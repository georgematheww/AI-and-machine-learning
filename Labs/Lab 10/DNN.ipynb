# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import numpy as np

dataset_path = '/content/dataset.csv'
dataset = pd.read_csv(dataset_path)


label_encoder = LabelEncoder()
dataset['classification'] = label_encoder.fit_transform(dataset['classification'])

X = dataset.drop(columns=['hash', 'classification'])
y = dataset['classification']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=2)

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=2)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')


def permutation_importance(model, X, y, metric, n_repeats=10):
    baseline_score = metric(model, X, y)
    scores = np.zeros((n_repeats, X.shape[1]))

    for i in range(X.shape[1]):
        X_permuted = X.copy()
        for n in range(n_repeats):
            np.random.shuffle(X_permuted[:, i])
            score = metric(model, X_permuted, y)
            scores[n, i] = baseline_score - score

    importances = np.mean(scores, axis=0)
    return importances

def accuracy_metric(model, X, y):
    _, accuracy = model.evaluate(X, y, verbose=0)
    return accuracy

importances = permutation_importance(model, X_test, y_test, accuracy_metric, n_repeats=10)

feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9199 - loss: 0.2060 - val_accuracy: 0.9903 - val_loss: 0.0385
# Epoch 2/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9846 - loss: 0.0505 - val_accuracy: 0.9961 - val_loss: 0.0142
# Epoch 3/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9907 - loss: 0.0290 - val_accuracy: 0.9977 - val_loss: 0.0083
# Epoch 4/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9933 - loss: 0.0215 - val_accuracy: 0.9983 - val_loss: 0.0061
# Epoch 5/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9951 - loss: 0.0162 - val_accuracy: 0.9973 - val_loss: 0.0064
# Epoch 6/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9951 - loss: 0.0160 - val_accuracy: 0.9980 - val_loss: 0.0051
# Epoch 7/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9955 - loss: 0.0146 - val_accuracy: 0.9985 - val_loss: 0.0033
# Epoch 8/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9957 - loss: 0.0138 - val_accuracy: 0.9991 - val_loss: 0.0038
# Epoch 9/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9961 - loss: 0.0121 - val_accuracy: 0.9988 - val_loss: 0.0030
# Epoch 10/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9969 - loss: 0.0104 - val_accuracy: 0.9998 - val_loss: 0.0024
# Epoch 11/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9962 - loss: 0.0121 - val_accuracy: 0.9996 - val_loss: 0.0038
# Epoch 12/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9963 - loss: 0.0126 - val_accuracy: 0.9992 - val_loss: 0.0020
# Epoch 13/50
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 0.9988 - val_loss: 0.0026
# Epoch 14/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9965 - loss: 0.0113 - val_accuracy: 0.9999 - val_loss: 0.0016
# Epoch 15/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9970 - loss: 0.0109 - val_accuracy: 0.9999 - val_loss: 0.0011
# Epoch 16/50
# 2000/2000 - 5s - 2ms/step - accuracy: 0.9973 - loss: 0.0093 - val_accuracy: 0.9995 - val_loss: 0.0021
# Epoch 17/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9965 - loss: 0.0119 - val_accuracy: 0.9999 - val_loss: 0.0014
# Epoch 18/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9972 - loss: 0.0094 - val_accuracy: 0.9999 - val_loss: 0.0011
# Epoch 19/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9971 - loss: 0.0102 - val_accuracy: 0.9969 - val_loss: 0.0072
# Epoch 20/50
# 2000/2000 - 5s - 2ms/step - accuracy: 0.9974 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 21/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9972 - loss: 0.0091 - val_accuracy: 0.9996 - val_loss: 0.0018
# Epoch 22/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9972 - loss: 0.0090 - val_accuracy: 0.9999 - val_loss: 7.7565e-04
# Epoch 23/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9976 - loss: 0.0092 - val_accuracy: 0.9988 - val_loss: 0.0030
# Epoch 24/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9969 - loss: 0.0104 - val_accuracy: 0.9999 - val_loss: 0.0011
# Epoch 25/50
# 2000/2000 - 5s - 2ms/step - accuracy: 0.9979 - loss: 0.0101 - val_accuracy: 0.9999 - val_loss: 0.0012
# Epoch 26/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 27/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9976 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 6.7493e-04
# Epoch 28/50
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9978 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 5.9546e-04
# Epoch 29/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9978 - loss: 0.0083 - val_accuracy: 0.9999 - val_loss: 0.0017
# Epoch 30/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9977 - loss: 0.0094 - val_accuracy: 0.9997 - val_loss: 0.0037
# Epoch 31/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9971 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 7.7869e-04
# Epoch 32/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9981 - loss: 0.0076 - val_accuracy: 0.9999 - val_loss: 6.7922e-04
# Epoch 33/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9977 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 5.7629e-04
# Epoch 34/50
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9977 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 5.3974e-04
# Epoch 35/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9980 - loss: 0.0071 - val_accuracy: 0.9999 - val_loss: 9.2419e-04
# Epoch 36/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9982 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 4.3738e-04
# Epoch 37/50
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9977 - loss: 0.0087 - val_accuracy: 0.9991 - val_loss: 0.0031
# Epoch 38/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9979 - loss: 0.0077 - val_accuracy: 0.9993 - val_loss: 9.6678e-04
# Epoch 39/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.9999 - val_loss: 2.9426e-04
# Epoch 40/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9980 - loss: 0.0096 - val_accuracy: 0.9999 - val_loss: 5.3390e-04
# Epoch 41/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 3.9422e-04
# Epoch 42/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9982 - loss: 0.0071 - val_accuracy: 0.9998 - val_loss: 0.0012
# Epoch 43/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9983 - loss: 0.0066 - val_accuracy: 0.9999 - val_loss: 4.3589e-04
# Epoch 44/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 2.3196e-04
# Epoch 45/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9980 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 2.4095e-04
# Epoch 46/50
# 2000/2000 - 3s - 2ms/step - accuracy: 0.9983 - loss: 0.0076 - val_accuracy: 0.9996 - val_loss: 0.0011
# Epoch 47/50
# 2000/2000 - 5s - 3ms/step - accuracy: 0.9983 - loss: 0.0068 - val_accuracy: 0.9999 - val_loss: 2.2269e-04
# Epoch 48/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9986 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 1.8488e-04
# Epoch 49/50
# 2000/2000 - 6s - 3ms/step - accuracy: 0.9979 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 7.2543e-05
# Epoch 50/50
# 2000/2000 - 4s - 2ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 4.2774e-05
# 625/625 - 1s - 1ms/step - accuracy: 1.0000 - loss: 5.0666e-05
# Test Loss: 5.0665868911892176e-05, Test Accuracy: 1.0
#               Feature  Importance
# 28              utime    0.320410
# 22              nvcsw    0.115985
# 12           mm_users    0.111015
# 20           end_data    0.095110
# 16          shared_vm    0.086240
# 21      last_interval    0.069500
# 4         static_prio    0.068385
# 25            maj_flt    0.059305
# 23             nivcsw    0.048230
# 17            exec_vm    0.042805
# 18        reserved_vm    0.033440
# 30              gtime    0.030470
# 13          map_count    0.029595
# 3                prio    0.028180
# 15           total_vm    0.025000
# 29              stime    0.021275
# 8   vm_truncate_count    0.015725
# 26    fs_excl_counter    0.006720
# 11    free_area_cache    0.004460
# 0         millisecond    0.000785
# 1               state    0.000405
# 24            min_flt    0.000300
# 19            nr_ptes    0.000000
# 14        hiwater_rss    0.000000
# 10   cached_hole_size    0.000000
# 9           task_size    0.000000
# 7            vm_pgoff    0.000000
# 27               lock    0.000000
# 6              policy    0.000000
# 5         normal_prio    0.000000
# 2       usage_counter    0.000000
# 31             cgtime    0.000000
# 32       signal_nvcsw    0.000000
